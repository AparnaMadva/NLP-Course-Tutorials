# %% [markdown]
# ## Constituency Parsing

# %% [markdown]
# This notebook covers submodules of nltk.parse package.
#
# <b>Parsing or syntax analysis or syntactic analysis</b> is the analysis of a string of symbols, conforming to the rules of a formal grammar.

# %% [markdown]
# #### Parsing using nltk.parse package

# %% [markdown]
# Reference - [nltk.parse package](https://www.nltk.org/api/nltk.parse.html)

# %%
import nltk
from nltk import nonterminals, Production, CFG
from nltk.parse.generate import generate

# %% [markdown]
# Each node in the parse tree is a constituent. A grammar specifies how the sentence can be subdivided into its immediate constituents

# %% [markdown]
# A <b>context-free grammar</b> G=(V,T,P,S) is composed of
#
# V : a set of variables / non-terminals
#
# T : a set of terminal symbols
#
# P : a set of productions, rules that recursively define the structure of the language.
#
# S : a starting symbol.
#
# A production has the form A→α where,
# A is a variable.
# α is a string of zero or more symbol, either terminals or variables.

# %%
S, NP, VP = nonterminals('S, NP, VP')
N, V, P, DT = nonterminals('N, V, P, DT')

rule1 = Production(S, [NP, VP])
rule2 = Production(NP, [DT, NP])

print(rule1)
print(rule2)
# Out:
# S -> NP VP
# NP -> DT NP

# %%
rule1.rhs()
# Out:
# (NP, VP)

# %%
grammar = CFG(S,[rule1,rule2])

grammar.productions()
# Out:
# [S -> NP VP, NP -> DT NP]

# %%
grammar = CFG.fromstring("""
S -> NP VP
VP -> V NP | V NP PP
PP -> P NP
V -> "saw" | "ate" | "walked" | "slept"
NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
Det -> "A" | "An" | "The" | "My" | "the" | "a"
N -> "man" | "dog" | "cat" | "telescope" | "park"
P -> "in" | "on" | "by" | "with"
""")
grammar.productions()
# Out:
# [S -> NP VP,
#  VP -> V NP,
#  VP -> V NP PP,
#  PP -> P NP,
#  V -> 'saw',
#  V -> 'ate',
#  V -> 'walked',
#  NP -> 'John',
#  NP -> 'Mary',
#  NP -> 'Bob',
#  NP -> Det N,
#  NP -> Det N PP,
#  Det -> 'A',
#  Det -> 'An',
#  Det -> 'The',
#  Det -> 'My',
#  Det -> 'the',
#  Det -> 'a',
#  N -> 'man',
#  N -> 'dog',
#  N -> 'cat',
#  N -> 'telescope',
#  N -> 'park',
#  P -> 'in',
#  P -> 'on',
#  P -> 'by',
#  P -> 'with']

# %%
#generating sample sentences from the CFG
for sentence in generate(grammar, n=10):
  print(' '.join(sentence))
# Out:
# John saw John
# John saw Mary
# John saw Bob
# John saw A man
# John saw A dog
# John saw A cat
# John saw A telescope
# John saw A park
# John saw An man
# John saw An dog

# %% [markdown]
# #### Recursive Descent Parser

# %% [markdown]
# <b>Recursive descent</b> is a top-down parsing technique that constructs the parse tree from the top and the input is read from left to right.
#
# The basic idea of recursive-descent parsing is to associate each non-terminal with a production. The goal of each such production is to read a sequence of input characters that can be generated by the corresponding non-terminal, and return a pointer to the root of the parse tree for the non-terminal.

# %% [markdown]
# The terminal symbol is compared to the input; if they agree, it consumes the terminal symbol in the input or 'match'.
# For a non-terminal symbol, the corresponding production is called or 'expand'.

# %%
from nltk.parse import RecursiveDescentParser
rd = RecursiveDescentParser(grammar,trace=0)

# %%
from nltk.parse.recursivedescent import demo
demo()
# Out:
# S -> NP VP
# NP -> Det N
# NP -> Det N PP
# VP -> V NP
# VP -> V NP PP
# PP -> P NP
# NP -> 'I'
# N -> 'man'
# N -> 'park'
# N -> 'telescope'
# N -> 'dog'
# Det -> 'the'
# Det -> 'a'
# P -> 'in'
# P -> 'with'
# V -> 'saw'
# Parsing 'I saw a man in the park'
#     [ * S ]
#   E [ * NP VP ]
#   E [ * Det N VP ]
#   E [ * 'the' N VP ]
#   E [ * 'a' N VP ]
#   E [ * Det N PP VP ]
#   E [ * 'the' N PP VP ]
#   E [ * 'a' N PP VP ]
#   E [ * 'I' VP ]
#   M [ 'I' * VP ]
#   E [ 'I' * V NP ]
#   E [ 'I' * 'saw' NP ]
#   M [ 'I' 'saw' * NP ]
#   E [ 'I' 'saw' * Det N ]
#   E [ 'I' 'saw' * 'the' N ]
#   E [ 'I' 'saw' * 'a' N ]
#   M [ 'I' 'saw' 'a' * N ]
#   E [ 'I' 'saw' 'a' * 'man' ]
#   M [ 'I' 'saw' 'a' 'man' ]
#   E [ 'I' 'saw' 'a' * 'park' ]
#   E [ 'I' 'saw' 'a' * 'telescope' ]
#   E [ 'I' 'saw' 'a' * 'dog' ]
#   E [ 'I' 'saw' * Det N PP ]
#   E [ 'I' 'saw' * 'the' N PP ]
#   E [ 'I' 'saw' * 'a' N PP ]
#   M [ 'I' 'saw' 'a' * N PP ]
#   E [ 'I' 'saw' 'a' * 'man' PP ]
#   M [ 'I' 'saw' 'a' 'man' * PP ]
#   E [ 'I' 'saw' 'a' 'man' * P NP ]
#   E [ 'I' 'saw' 'a' 'man' * 'in' NP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' * NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * Det N ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'the' N ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' * N ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'man' ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'park' ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' ]
#   + [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' ]
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP (Det a) (N man) (PP (P in) (NP (Det the) (N park))))))
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'telescope' ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'dog' ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'a' N ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * Det N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'the' N PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' * N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'man' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'park' PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * P NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'in' NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'with' NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'telescope' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'dog' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'a' N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'I' ]
#   E [ 'I' 'saw' 'a' 'man' * 'with' NP ]
#   E [ 'I' 'saw' 'a' * 'park' PP ]
#   E [ 'I' 'saw' 'a' * 'telescope' PP ]
#   E [ 'I' 'saw' 'a' * 'dog' PP ]
#   E [ 'I' 'saw' * 'I' ]
#   E [ 'I' * V NP PP ]
#   E [ 'I' * 'saw' NP PP ]
#   M [ 'I' 'saw' * NP PP ]
#   E [ 'I' 'saw' * Det N PP ]
#   E [ 'I' 'saw' * 'the' N PP ]
#   E [ 'I' 'saw' * 'a' N PP ]
#   M [ 'I' 'saw' 'a' * N PP ]
#   E [ 'I' 'saw' 'a' * 'man' PP ]
#   M [ 'I' 'saw' 'a' 'man' * PP ]
#   E [ 'I' 'saw' 'a' 'man' * P NP ]
#   E [ 'I' 'saw' 'a' 'man' * 'in' NP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' * NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * Det N ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'the' N ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' * N ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'man' ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'park' ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' ]
#   + [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' ]
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP (Det a) (N man))
#     (PP (P in) (NP (Det the) (N park)))))
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'telescope' ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'dog' ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'a' N ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * Det N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'the' N PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' * N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'man' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'park' PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * P NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'in' NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'with' NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'telescope' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'dog' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'a' N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'I' ]
#   E [ 'I' 'saw' 'a' 'man' * 'with' NP ]
#   E [ 'I' 'saw' 'a' * 'park' PP ]
#   E [ 'I' 'saw' 'a' * 'telescope' PP ]
#   E [ 'I' 'saw' 'a' * 'dog' PP ]
#   E [ 'I' 'saw' * Det N PP PP ]
#   E [ 'I' 'saw' * 'the' N PP PP ]
#   E [ 'I' 'saw' * 'a' N PP PP ]
#   M [ 'I' 'saw' 'a' * N PP PP ]
#   E [ 'I' 'saw' 'a' * 'man' PP PP ]
#   M [ 'I' 'saw' 'a' 'man' * PP PP ]
#   E [ 'I' 'saw' 'a' 'man' * P NP PP ]
#   E [ 'I' 'saw' 'a' 'man' * 'in' NP PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' * NP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * Det N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'the' N PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' * N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'man' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'park' PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * P NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'in' NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'with' NP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'telescope' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'dog' PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'a' N PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * Det N PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'the' N PP PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' * N PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'man' PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'park' PP PP ]
#   M [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * P NP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'in' NP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' 'park' * 'with' NP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'telescope' PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' 'the' * 'dog' PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'a' N PP PP ]
#   E [ 'I' 'saw' 'a' 'man' 'in' * 'I' PP ]
#   E [ 'I' 'saw' 'a' 'man' * 'with' NP PP ]
#   E [ 'I' 'saw' 'a' * 'park' PP PP ]
#   E [ 'I' 'saw' 'a' * 'telescope' PP PP ]
#   E [ 'I' 'saw' 'a' * 'dog' PP PP ]
#   E [ 'I' 'saw' * 'I' PP ]

# %%
sentence1 = 'Mary saw Bob'.split()
sentence2 = 'The dog saw a man in the park'.split()
print(sentence1,"\n",sentence2)
# Out:
# ['Mary', 'saw', 'Bob']
#  ['The', 'dog', 'saw', 'a', 'man', 'in', 'the', 'park']

# %%
trees = rd.parse(sentence1)

for t in trees:
  print(t)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %%
# the sentence does not belong to the grammar
for t in rd.parse("Mary Bob".split()):
  print(t)

# %%
for t in rd.parse(sentence2):
  print(t)
# Out:
# (S
#   (NP (Det The) (N dog))
#   (VP
#     (V saw)
#     (NP (Det a) (N man) (PP (P in) (NP (Det the) (N park))))))
# (S
#   (NP (Det The) (N dog))
#   (VP
#     (V saw)
#     (NP (Det a) (N man))
#     (PP (P in) (NP (Det the) (N park)))))

# %% [markdown]
# ##### Left recursion example

# %% [markdown]
# A left recursive production can send RD parser into an infinite loop.

# %%
## NP -> NP P is the left recursive production
lrgrammar = CFG.fromstring("""
S -> NP V 
NP -> NP P | "John" | "Mary" | "Bob" | "Tom" 
P -> "are"
V -> "beautiful"
""")
lrgrammar.productions()
# Out:
# [S -> NP V,
#  NP -> NP P,
#  NP -> 'John',
#  NP -> 'Mary',
#  NP -> 'Bob',
#  NP -> 'Tom',
#  P -> 'are',
#  V -> 'beautiful']

# %%
lrparser = RecursiveDescentParser(lrgrammar)

# %%
sent = "John Mary Bob Tom are beautiful".split()
for t in lrparser.parse(sent):
  print(t)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-16-31e6647a22b1> in <module>
#       1 sent = "John Mary Bob Tom are beautiful".split()
# ----> 2 for t in lrparser.parse(sent):
#       3   print(t)
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
# ...
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     223                 if self._trace:
#     224                     self._trace_expand(newtree, new_frontier, production)
# --> 225                 yield from self._parse(
#     226                     remaining_text, newtree, new_frontier + frontier[1:]
#     227                 )
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     124         # If the next element on the frontier is a tree, expand it.
#     125         elif isinstance(tree[frontier[0]], Tree):
# --> 126             yield from self._expand(remaining_text, tree, frontier)
#     127
#     128         # If the next element on the frontier is a token, match it.
#
# /usr/local/lib/python3.9/dist-packages/nltk/parse/recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     216                     newtree = subtree
#     217                 else:
# --> 218                     newtree = tree.copy(deep=True)
#     219                     newtree[frontier[0]] = subtree
#     220                 new_frontier = [
#
# /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py in copy(self, deep)
#     556             return type(self)(self._label, self)
#     557         else:
# --> 558             return type(self).convert(self)
#     559
#     560     def _frozen_class(self):
#
# /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py in convert(cls, tree)
#     541         """
#     542         if isinstance(tree, Tree):
# --> 543             children = [cls.convert(child) for child in tree]
#     544             return cls(tree._label, children)
#     545         else:
#
# /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py in <listcomp>(.0)
#     541         """
#     542         if isinstance(tree, Tree):
# --> 543             children = [cls.convert(child) for child in tree]
#     544             return cls(tree._label, children)
#     545         else:
#
# ... last 2 frames repeated, from the frame below ...
#
# /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py in convert(cls, tree)
#     541         """
#     542         if isinstance(tree, Tree):
# --> 543             children = [cls.convert(child) for child in tree]
#     544             return cls(tree._label, children)
#     545         else:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# #### Shift Reduce Parser

# %% [markdown]
# Top-down parsers use a grammar to predict what the input will be, before inspecting the input. Since the input is available all along, it would be more sensible to consider the input sentence from the very beginning.

# %% [markdown]
# The advantage of shift-reduce parsers over recursive descent parsers is that they only build structure that corresponds to the words in the input.

# %% [markdown]
# *Shift Reduce parser* follows bottom-up parsing technique, constructing parse tree is constructed from leaves(bottom) to the root(up).

# %% [markdown]
# Shift : The parser repeatedly pushes the next input word onto a stack.
#
# Reduce : Replacement of the stack's top with a single non-terminal.
#
# If the top n items on the stack match the n items on the right hand side of some production, then they are all popped off the stack, and the item on the left-hand side of the production is pushed on the stack. The parser finishes when all the input is consumed and there is only one item remaining on the stack, a parse tree with an S node as its root.

# %%
from nltk.parse import ShiftReduceParser
sr = ShiftReduceParser(grammar,trace=0)

# %%
from nltk.parse.shiftreduce import demo
demo()
# Out:
# Parsing 'I saw a man in the park'
#     [ * I saw a man in the park]
#   S [ 'I' * saw a man in the park]
#   R [ NP * saw a man in the park]
#   S [ NP 'saw' * a man in the park]
#   R [ NP V * a man in the park]
#   S [ NP V 'a' * man in the park]
#   R [ NP V Det * man in the park]
#   S [ NP V Det 'man' * in the park]
#   R [ NP V Det N * in the park]
#   R [ NP V NP * in the park]
#   R [ NP VP * in the park]
#   R [ S * in the park]
#   S [ S 'in' * the park]
#   R [ S P * the park]
#   S [ S P 'the' * park]
#   R [ S P Det * park]
#   S [ S P Det 'park' * ]
#   R [ S P Det N * ]
#   R [ S P NP * ]
#   R [ S PP * ]

# %%
#sentence1 = 'Mary saw Bob'

for t in sr.parse(sentence1):
  print(t)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %% [markdown]
# This parser does not implement any backtracking, so it is not guaranteed to find a parse for a text, even if one exists.
#
# A shift-reduce parser can reach a dead end and fail to find any parse, even if the input sentence is well-formed according to the grammar. The problem arises because there are choices made earlier that cannot be undone by the parser.

# %%
#sentence2 = 'The dog saw a man in the park'
tree = sr.parse(sentence2)
for t in tree:
  print(t)

# %%
#trace for sentence2
sr = ShiftReduceParser(grammar,trace=2)
tree = sr.parse(sentence2)
for t in tree:
  print(t)
# Out:
# Parsing 'The dog saw a man in the park'
#     [ * The dog saw a man in the park]
#   S [ 'The' * dog saw a man in the park]
#   R [ Det * dog saw a man in the park]
#   S [ Det 'dog' * saw a man in the park]
#   R [ Det N * saw a man in the park]
#   R [ NP * saw a man in the park]
#   S [ NP 'saw' * a man in the park]
#   R [ NP V * a man in the park]
#   S [ NP V 'a' * man in the park]
#   R [ NP V Det * man in the park]
#   S [ NP V Det 'man' * in the park]
#   R [ NP V Det N * in the park]
#   R [ NP V NP * in the park]
#   R [ NP VP * in the park]
#   R [ S * in the park]
#   S [ S 'in' * the park]
#   R [ S P * the park]
#   S [ S P 'the' * park]
#   R [ S P Det * park]
#   S [ S P Det 'park' * ]
#   R [ S P Det N * ]
#   R [ S P NP * ]
#   R [ S PP * ]

# %% [markdown]
# Resources :
#
# [Analyzing sentence structure](https://www.nltk.org/book/ch08.html#code-cfg2)
#
# [Parsing with corenlp](https://github.com/nltk/nltk/wiki/Stanford-CoreNLP-API-in-NLTK)

# %% [markdown]
# ## Dependency Parsing

# %% [markdown]
# <b>Dependency grammar</b> focusses on how words relate to other words, instead of how words and sequences of words combine to form constituents.
#  Dependency is a binary asymmetric relation that holds between a head and its dependents.

# %% [markdown]
# The head of a sentence is usually taken to be the tensed verb, and every other word is either dependent on the sentence head, or connects to it through a path of dependencies.

# %% [markdown]
# [Universal dependency relations](https://universaldependencies.org/u/dep/) contains list of possible dependency relations in the graph.

# %% [markdown]
# #### 1. Dependency parsing using spaCy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
from spacy import displacy
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
doc = nlp("My brother’s dog barks a lot")
displacy.render(doc,style='dep',jupyter=True, options={'distance': 150})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="eef05806d2cb41aba5f304c56dbc73e3-0" class="displacy" width="1100" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">brother</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">barks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">lot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eef05806d2cb41aba5f304c56dbc73e3-0-0" stroke-width="2px" d="M70,152.0 C70,77.0 195.0,77.0 195.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eef05806d2cb41aba5f304c56dbc73e3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eef05806d2cb41aba5f304c56dbc73e3-0-1" stroke-width="2px" d="M220,152.0 C220,2.0 500.0,2.0 500.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eef05806d2cb41aba5f304c56dbc73e3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,154.0 L212,142.0 228,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eef05806d2cb41aba5f304c56dbc73e3-0-2" stroke-width="2px" d="M220,152.0 C220,77.0 345.0,77.0 345.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eef05806d2cb41aba5f304c56dbc73e3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M345.0,154.0 L353.0,142.0 337.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eef05806d2cb41aba5f304c56dbc73e3-0-3" stroke-width="2px" d="M520,152.0 C520,77.0 645.0,77.0 645.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eef05806d2cb41aba5f304c56dbc73e3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,154.0 L512,142.0 528,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eef05806d2cb41aba5f304c56dbc73e3-0-4" stroke-width="2px" d="M820,152.0 C820,77.0 945.0,77.0 945.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eef05806d2cb41aba5f304c56dbc73e3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M820,154.0 L812,142.0 828,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eef05806d2cb41aba5f304c56dbc73e3-0-5" stroke-width="2px" d="M670,152.0 C670,2.0 950.0,2.0 950.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eef05806d2cb41aba5f304c56dbc73e3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950.0,154.0 L958.0,142.0 942.0,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
doc = nlp("Cats hate water")
displacy.render(doc,style='dep',jupyter=True, options={'distance': 100})
for token in doc:
    print(token.text,"\t", token.dep_,"\t\t","Head of this token is :", token.head.text)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="daee0068f1094582b09745a2ce240d46-0" class="displacy" width="350" height="187.0" direction="ltr" style="max-width: none; height: 187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Cats</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">hate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">water</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daee0068f1094582b09745a2ce240d46-0-0" stroke-width="2px" d="M70,52.0 C70,2.0 150.0,2.0 150.0,52.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daee0068f1094582b09745a2ce240d46-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,54.0 L62,42.0 78,42.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daee0068f1094582b09745a2ce240d46-0-1" stroke-width="2px" d="M170,52.0 C170,2.0 250.0,2.0 250.0,52.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daee0068f1094582b09745a2ce240d46-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250.0,54.0 L258.0,42.0 242.0,42.0" fill="currentColor"/>
# </g>
# </svg></span>
# Cats 	 nsubj 		 Head of this token is : hate
# hate 	 ROOT 		 Head of this token is : hate
# water 	 dobj 		 Head of this token is : hate

# %%
doc = nlp("Children had fruits , snacks and cookies")
displacy.render(doc,style='dep',jupyter=True, options={'distance': 100})
for token in doc:
    print("{0}({1}-{2}, {3}-{4})".format(token.dep_, token.head.text, token.head.i+1, token.text,  token.i+1, ))
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f31f579c8b7f45a3abac85f60adcaf63-0" class="displacy" width="650" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">fruits ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">snacks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">cookies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f31f579c8b7f45a3abac85f60adcaf63-0-0" stroke-width="2px" d="M70,102.0 C70,52.0 145.0,52.0 145.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f31f579c8b7f45a3abac85f60adcaf63-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,104.0 L62,92.0 78,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f31f579c8b7f45a3abac85f60adcaf63-0-1" stroke-width="2px" d="M170,102.0 C170,52.0 245.0,52.0 245.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f31f579c8b7f45a3abac85f60adcaf63-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245.0,104.0 L253.0,92.0 237.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f31f579c8b7f45a3abac85f60adcaf63-0-2" stroke-width="2px" d="M270,102.0 C270,52.0 345.0,52.0 345.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f31f579c8b7f45a3abac85f60adcaf63-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M345.0,104.0 L353.0,92.0 337.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f31f579c8b7f45a3abac85f60adcaf63-0-3" stroke-width="2px" d="M370,102.0 C370,52.0 445.0,52.0 445.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f31f579c8b7f45a3abac85f60adcaf63-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,104.0 L453.0,92.0 437.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f31f579c8b7f45a3abac85f60adcaf63-0-4" stroke-width="2px" d="M370,102.0 C370,2.0 550.0,2.0 550.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f31f579c8b7f45a3abac85f60adcaf63-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550.0,104.0 L558.0,92.0 542.0,92.0" fill="currentColor"/>
# </g>
# </svg></span>
# nsubj(had-2, Children-1)
# ROOT(had-2, had-2)
# dobj(had-2, fruits-3)
# punct(fruits-3, ,-4)
# conj(fruits-3, snacks-5)
# cc(snacks-5, and-6)
# conj(snacks-5, cookies-7)

# %%
token_array = [token for token in doc]
print("for the token 'Snacks', n_lefts = ",token_array[4].n_lefts," n_rights = ",token_array[4].n_rights)
print("for the token 'had', n_lefts = ",token_array[1].n_lefts," n_rights = ",token_array[1].n_rights)
# Out:
# for the token 'Snacks', n_lefts =  0  n_rights =  2
# for the token 'had', n_lefts =  1  n_rights =  1

# %%
print("Is 'had' the ancestor of 'fruits'? ",token_array[1].is_ancestor(token_array[2]))
# Out:
# Is 'had' the ancestor of 'fruits'?  True

# %% [markdown]
# [Parsing English in 500 Lines of Python](https://explosion.ai/blog/parsing-english-in-python) is by MATTHEW HONNIBAL, who wrote spaCy.

# %% [markdown]
# #### 2. Dependency parsing using nltk

# %%
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph ,ProjectiveDependencyParser

# %%
from nltk.parse.projectivedependencyparser import demo
demo()
# Out:
# Dependency grammar with 4 productions
#   'scratch' -> 'cats'
#   'scratch' -> 'walls'
#   'walls' -> 'the'
#   'cats' -> 'the'
# (scratch (cats the) (walls the))
# Training Probabilistic Projective Dependency Parser...
# Parsing ' Cathy zag hen wild zwaaien . '...
# Parse:
# (zag Cathy hen (zwaaien wild .))

# %%
dep_grammar = DependencyGrammar.fromstring("""
'shot' -> 'I' | 'elephant' | 'in'
'elephant' -> 'an' | 'in'
'in' -> 'pajamas'
'pajamas' -> 'my'
""")
print(dep_grammar)
# Out:
# Dependency grammar with 7 productions
#   'shot' -> 'I'
#   'shot' -> 'elephant'
#   'shot' -> 'in'
#   'elephant' -> 'an'
#   'elephant' -> 'in'
#   'in' -> 'pajamas'
#   'pajamas' -> 'my'

# %%
pdparser = ProjectiveDependencyParser(dep_grammar)
sent = 'I shot an elephant in Nigeria'.split()
trees = pdparser.parse(sent)
for t in trees:
     print(t)

# %%
#visualise using displacy
doc = nlp("I shot an elephant in my pajamas")
displacy.render(doc,style='dep',jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="93239e60dcd3499a84f840417b215402-0" class="displacy" width="750" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">shot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">elephant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">pajamas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93239e60dcd3499a84f840417b215402-0-0" stroke-width="2px" d="M70,152.0 C70,102.0 140.0,102.0 140.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93239e60dcd3499a84f840417b215402-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93239e60dcd3499a84f840417b215402-0-1" stroke-width="2px" d="M270,152.0 C270,102.0 340.0,102.0 340.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93239e60dcd3499a84f840417b215402-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,154.0 L262,142.0 278,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93239e60dcd3499a84f840417b215402-0-2" stroke-width="2px" d="M170,152.0 C170,52.0 345.0,52.0 345.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93239e60dcd3499a84f840417b215402-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M345.0,154.0 L353.0,142.0 337.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93239e60dcd3499a84f840417b215402-0-3" stroke-width="2px" d="M170,152.0 C170,2.0 450.0,2.0 450.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93239e60dcd3499a84f840417b215402-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,154.0 L458.0,142.0 442.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93239e60dcd3499a84f840417b215402-0-4" stroke-width="2px" d="M570,152.0 C570,102.0 640.0,102.0 640.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93239e60dcd3499a84f840417b215402-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,154.0 L562,142.0 578,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93239e60dcd3499a84f840417b215402-0-5" stroke-width="2px" d="M470,152.0 C470,52.0 645.0,52.0 645.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93239e60dcd3499a84f840417b215402-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,154.0 L653.0,142.0 637.0,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
grammar2 = DependencyGrammar.fromstring("""
'ate' -> 'children' | 'cake' | 'with' | 'spoon'
'children' -> 'The'
'cake' ->  'the'
'with' -> 'spoon'
'spoon' -> 'a'
""")
pdparser = ProjectiveDependencyParser(grammar2)

# %%
sent = 'The children ate the cake with a spoon'.split()
trees = pdparser.parse(sent)
for t in trees:
     print(t)
# Out:
# (ate (children The) (cake the) with (spoon a))
# (ate (children The) (cake the) (with (spoon a)))

# %%
#visualise using displacy
doc = nlp("The city council refused permission to the protesters because they feared violence")
displacy.render(doc,style='dep',jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b98d5549d348446da96be7a16915cdd6-0" class="displacy" width="1250" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">refused</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">permission</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">protesters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">feared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">violence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-0" stroke-width="2px" d="M70,152.0 C70,52.0 245.0,52.0 245.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,154.0 L162,142.0 178,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-2" stroke-width="2px" d="M270,152.0 C270,102.0 340.0,102.0 340.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,154.0 L262,142.0 278,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-3" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M440.0,154.0 L448.0,142.0 432.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-4" stroke-width="2px" d="M470,152.0 C470,102.0 540.0,102.0 540.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M540.0,154.0 L548.0,142.0 532.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-5" stroke-width="2px" d="M670,152.0 C670,102.0 740.0,102.0 740.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,154.0 L662,142.0 678,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-6" stroke-width="2px" d="M570,152.0 C570,52.0 745.0,52.0 745.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,154.0 L753.0,142.0 737.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b98d5549d348446da96be7a16915cdd6-0-7" stroke-width="2px" d="M870,152.0 C870,52.0 1045.0,52.0 1045.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b98d5549d348446da96be7a16915cdd6-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,154.0 L862,142.0 878,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="dis

# %% [markdown]
# ##### Using Treebank data

# %%
#from nltk.corpus import dependency_treebank

# %%
# fields are word | tag | head | relation
treebank_data = """
Pierre  NNP     2       NMOD
Vinken  NNP     8       SUB
,       ,       2       P
61      CD      5       NMOD
years   NNS     6       AMOD
old     JJ      2       NMOD
,       ,       2       P
will    MD      0       ROOT
join    VB      8       VC
the     DT      11      NMOD
board   NN      9       OBJ
as      IN      9       VMOD
a       DT      15      NMOD
nonexecutive    JJ      15      NMOD
director        NN      12      PMOD
Nov.    NNP     9       VMOD
29      CD      16      NMOD
.       .       9       VMOD
"""

# %%
dg = DependencyGraph(treebank_data)
dg.tree().pprint()
# Out:
# (will
#   (Vinken Pierre , (old (years 61)) ,)
#   (join (board the) (as (director a nonexecutive)) (Nov. 29) .))

# %% [markdown]
# ## demo

# %%
#!pip install -U nltk

# %%
import nltk
from nltk.app import rdparser_app,srparser_app,chartparser_app

# %%
rdparser_app.app()

# %%
srparser_app.app()
